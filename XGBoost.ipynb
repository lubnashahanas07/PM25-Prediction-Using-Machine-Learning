# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'data/final_integrated_data.csv')
df = df.sort_values("Timestamp").reset_index(drop= True)
df.shape
# Out:
# (29222, 52)

# %%
y = df["PM2.5 (µg/m³)"]
y.shape
# Out:
# (29222,)

# %%
compo_met_variables = ['co', 'aermr04', 'aermr05', 'aermr06', 'aermr09', 'aermr07', 'aermr10',
       'aermr08', 'no2', 'no', 'go3','so2','q','t','u10', 'v10', 'd2m', 't2m']

X = df[compo_met_variables]
X.shape
# Out:
# (29222, 18)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.20,shuffle= False)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((23377, 18), (5845, 18), (23377,), (5845,))

# %%
from xgboost import XGBRegressor

# %%
model = XGBRegressor(
    learning_rate = 0.05,
    max_depth = 5,
    n_estimators = 200,
    random_state=42
)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
y_pred
# Out:
# array([131.09361, 205.92099, 239.86946, ..., 216.4075 , 223.82329,
#        223.18843], shape=(5845,), dtype=float32)

# %%
# model evaluation

from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import numpy as np

r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print("R²:", r2)
print("MAE:", mae)
print("RMSE:", rmse)
# Out:
# R²: 0.658933590342506
# MAE: 44.408007791859276
# RMSE: 66.9533158638165
